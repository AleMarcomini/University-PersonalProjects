# %% [markdown]
# # Hands-on exercise
#
# In this simple example you are required to perform a simple linear regression with scipy. Find all the information on the function in the documentation: https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.linregress.html

# %%
import matplotlib.pyplot as plt
import csv
from scipy import stats
import numpy as np
import numpy.random as npr
import sklearn as sl
from sklearn import linear_model
from sklearn.linear_model import LinearRegression

def l2loss(h,x,y):
    l = (h(x)-y)**2
    return l

# %%
# Load the provided .csv file with the used car data

filename = "data/km_year_power_price.csv"
lines = csv.reader(open(filename, newline=''), delimiter=',')

# place your loading code here

dataset = list(lines)
dataset.pop(0)
n = len(dataset)
for i in range(n):
    dataset[i] = [float(x) for x in dataset[i]]
datarray = np.array(dataset)
npr.shuffle(datarray)
test_set = datarray[0:int(0.25*n),:]
tr_set = datarray[int(0.25*n):,:]

# %% [markdown]
# Use a linear regression to estimate the car prices from the year, kilometers or engine power.
# You can make a simple 1D regression from each one of the parameters independently

# %%
# linear regression with linregress (estimate price from year)

# your code.....

#price from km
x,y = tr_set[:,0],tr_set[:,3]
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
print(slope, intercept, r_value, p_value, std_err)

plt.plot(x, y, 'o', label='original data')
plt.plot(x, intercept + slope*x, 'r', label='fitted line')
plt.legend()
plt.show()

def h(x): return slope*x+intercept

test_error = 0
for i in range(len(test_set)):
    test_error += l2loss(h,test_set[i,0],test_set[i,3])

print('test error:', test_error)






#price from year
x,y = tr_set[:,1],tr_set[:,3]
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
print(slope, intercept, r_value, p_value, std_err)

plt.plot(x, y, 'o', label='original data')
plt.plot(x, intercept + slope*x, 'r', label='fitted line')
plt.legend()
plt.show()

def h(x): return slope*x+intercept

test_error = 0
for i in range(len(test_set)):
    test_error += l2loss(h,test_set[i,1],test_set[i,3])

print('test error:', test_error)






#price from power
x,y = tr_set[:,2],tr_set[:,3]
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
print(slope, intercept, r_value, p_value, std_err)

plt.plot(x, y, 'o', label='original data')
plt.plot(x, intercept + slope*x, 'r', label='fitted line')
plt.legend()
plt.show()

def h(x): return slope*x+intercept

test_error = 0
for i in range(len(test_set)):
    test_error += l2loss(h,test_set[i,2],test_set[i,3])

print('test error:', test_error)
# Out:
# -0.0573673284126006 16849.989357506936 -0.2814029857475562 3.621883549231991e-19 0.006277863654803894
# test error: 26865229738.00565
# 1464.0893577951924 -2928057.939197383 0.6733424723999938 1.666766809546356e-129 51.58942793346742
# test error: 14788485196.99934
# 87.12152738796885 -844.6185722862174 0.6951862510876211 2.236015315129307e-141 2.8909506512072576
# test error: 12565982301.048782

# %%
# (Optional) linear regression with linear_model.LinearRegression() (estimate price from year)

# your code.....
X = training_set[:,:2]
y = training_set[:,3]
reg = LinearRegression().fit(X, y)
print(reg.score(X, y),reg.coef_,reg.intercept_)



reg.predict(np.array([[3, 5]]))
# Out:
# 0.45881293327781847 [9.55754993e-05 1.51642492e+03] -3032975.7580152187
# array([-3025393.63313738])

# %%
# linear regression with least squares (estimate price from year)
# You should get exactly the same solution of linregress !

# your code.....

# %%
# Plot the data and the lines representing the output of the linregress and least square algorithms

# your code....

# %%
# linear regression with linregress (estimate price from power)

# your code.....

# %%
# linear regression with linregress (estimate price from km)

# your code...

# %%
# Have a look at the correlation coefficients to see which of the 3 features works better

# your code......

# %%
# Optional : 2D linear regression with linear model (estimate price from year and power)


# your code......
